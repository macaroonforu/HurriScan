# %% [markdown]
# ## Data Preprocessing

# %%
#Terminal Commands (mostly for installing libraries we don't have)
# %pip install netCDF4
# %pip install requests
# %pip install lxml
# %pip install bs4
# Out:
# Requirement already satisfied: netCDF4 in /usr/local/lib/python3.10/dist-packages (1.6.5)
# Requirement already satisfied: cftime in /usr/local/lib/python3.10/dist-packages (from netCDF4) (1.6.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from netCDF4) (2023.7.22)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from netCDF4) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.7.22)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (4.9.3)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.10/dist-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.5)

# %%
#Import Statements

#Machine Learning
import numpy as np
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torch.utils.data.sampler import SubsetRandomSampler
import torchvision.transforms as transforms

#Data
import netCDF4 as nc
import os
import requests
import lxml
import bs4
import pandas as pd
import tarfile

#Data Visualization
import matplotlib.pyplot as plt

#Upload to Google Drive
import shutil

# %%
#Data Acquisition & Cleaning for Hurdat 2 Data

#Name of Hurriscan Data Folder
folderName = "HurriScan_Data"

#First check if the user already has the required data (so we do not have to download multiple times)
os.chdir("/content")
currDir = os.listdir()

print(currDir)

if (not(folderName in currDir)):
  #First let's get the Hurdat Data
  res = requests.get("https://www.nhc.noaa.gov/data/hurdat/hurdat2-1851-2022-050423.txt")

  soup = bs4.BeautifulSoup(res.text, "lxml")

  #Write the soup to a file
  path = os.curdir + "/" + folderName
  os.mkdir(path)
  os.chdir(path)

  #Write text file of Hurdat 2 data (6.6 MB)
  f = open('Hurdat.txt', "w+")
  f.write(soup.text)
  f.close

  #Now, let us read this data into a database (table)
  #For this, we will be adapting the code from https://github.com/metemaad/HURDAT2_processor/blob/master/HURDAT2_processor.py

Record_identifier_dic={
'C':"Closest approach to a coast, not followed by a landfall"
,'G':"Genesis"
,'I':"An intensity peak in terms of both pressure and wind"
,'L':"Landfall (center of system crossing a coastline)"
,'P':"Minimum in central pressure"
,'R':"Provides additional detail on the intensity of the cyclone when rapid changes are underway"
,'S':"Change of status of the system"
,'T':"Provides additional detail on the track (position) of the cyclone"
,'W':"Maximum sustained wind speed"}


Status_of_system_dic={
'TD':"Tropical cyclone of tropical depression intensity (< 34 knots)"
,'TS':"Tropical cyclone of tropical storm intensity (34-63 knots)"
,'HU':"Tropical cyclone of hurricane intensity (> 64 knots)"
,'EX':"Extratropical cyclone (of any intensity)"
,'SD':"Subtropical cyclone of subtropical depression intensity (< 34 knots)"
,'SS':"Subtropical cyclone of subtropical storm intensity (> 34 knots)"
,'LO':"A low that is neither a tropical cyclone, a subtropical cyclone, nor an extratropical cyclone (of any intensity)"
,'WV':"Tropical Wave (of any intensity)"
,'DB':"Disturbance (of any intensity)"}

def process_details(data):
    data=data.split(',')
    Year=int(data[0][0:4])
    Month=int(data[0][4:6])
    Day=int(data[0][6:8])
    Hours_in_UTC=int(data[1][0:2])
    Minutes_in_UTC=int(data[1][2:4])
    Record_identifier=data[2].strip()
    try:
        Record_identifier_desc=Record_identifier_dic[data[2].strip()]
    except:
        Record_identifier_desc=None

    Status_of_system=data[3].strip()
    try:
        Status_of_system_desc=Status_of_system_dic[Status_of_system]
    except:
        Status_of_system_desc=None

    if data[4].strip()[-1:] in ('N','S'):
        if data[4].strip()[-1:]=='N':
            Latitude=float(data[4].strip()[:-1])
        else:
            Latitude=-1.0*float(data[4].strip()[:-1])
    else:
        Latitude=-999

    if data[5].strip()[-1:] in ('E','W'):
        if data[5].strip()[-1:]=='E':
            Longitude=float(data[5].strip()[:-1])
        else:
            Longitude=-1.0*float(data[5].strip()[:-1])
    else:
        Longitude=-999
    Maximum_sustained_wind_in_knots=float(data[6].strip())
    Minimum_Pressure_in_millibars=float(data[7].strip())
    i=8
    F34_kt_wind_radii_maximum_northeastern=float(data[i].strip())
    i+=1
    F34_kt_wind_radii_maximum_southeastern=float(data[i].strip())
    i+=1
    F34_kt_wind_radii_maximum_southwestern=float(data[i].strip())
    i+=1
    F34_kt_wind_radii_maximum_northwestern=float(data[i].strip())


    i+=1
    F50_kt_wind_radii_maximum_northeastern=float(data[i].strip())
    i+=1
    F50_kt_wind_radii_maximum_southeastern=float(data[i].strip())
    i+=1
    F50_kt_wind_radii_maximum_southwestern=float(data[i].strip())
    i+=1
    F50_kt_wind_radii_maximum_northwestern=float(data[i].strip())

    i+=1
    F64_kt_wind_radii_maximum_northeastern=float(data[i].strip())
    i+=1
    F64_kt_wind_radii_maximum_southeastern=float(data[i].strip())
    i+=1
    F64_kt_wind_radii_maximum_southwestern=float(data[i].strip())
    i+=1
    F64_kt_wind_radii_maximum_northwestern=float(data[i].strip())



    res=Year,Month,Day,Hours_in_UTC,Minutes_in_UTC,Record_identifier,Record_identifier_desc,Status_of_system,Status_of_system_desc,Latitude,Longitude,Maximum_sustained_wind_in_knots,Minimum_Pressure_in_millibars,F34_kt_wind_radii_maximum_northeastern,F34_kt_wind_radii_maximum_southeastern,F34_kt_wind_radii_maximum_southwestern,F34_kt_wind_radii_maximum_northwestern,F50_kt_wind_radii_maximum_northeastern,F50_kt_wind_radii_maximum_southeastern,F50_kt_wind_radii_maximum_southwestern,F50_kt_wind_radii_maximum_northwestern,F64_kt_wind_radii_maximum_northeastern,F64_kt_wind_radii_maximum_southeastern,F64_kt_wind_radii_maximum_southwestern,F64_kt_wind_radii_maximum_northwestern
    return res

def process_header(data):
    data=data.split(',')
    Basin,ATCF_cyclone_number_for_that_year,Year,Name,Number_of_best_track_entries=data[0][0:2],data[0][2:4],data[0][4:8],data[1].strip(),data[2].strip()
    res=Basin,ATCF_cyclone_number_for_that_year,Year,Name,Number_of_best_track_entries
    return res


def identify_line_type(data):
    #print(data.split(',')) #Commented out because printing is slow and has lots of output
    if len(data.split(','))>4:
        return 2
    else:
        return 1
def columns_name():
    res=['Basin','ATCF_cyclone_number_for_that_year','Year_','Name',
         #'Number_of_best_track_entries',
         'Year','Month','Day','Hours_in_UTC','Minutes_in_UTC',
         'Record_identifier','Record_identifier_desc','Status_of_system','Status_of_system_desc','Latitude','Longitude'
         ,'Maximum_sustained_wind_in_knots','Minimum_Pressure_in_millibars','F34_kt_wind_radii_maximum_northeastern',
         'F34_kt_wind_radii_maximum_southeastern','F34_kt_wind_radii_maximum_southwestern',
         'F34_kt_wind_radii_maximum_northwestern','F50_kt_wind_radii_maximum_northeastern',
         'F50_kt_wind_radii_maximum_southeastern','F50_kt_wind_radii_maximum_southwestern',
         'F50_kt_wind_radii_maximum_northwestern','F64_kt_wind_radii_maximum_northeastern',
         'F64_kt_wind_radii_maximum_southeastern','F64_kt_wind_radii_maximum_southwestern',
         'F64_kt_wind_radii_maximum_northwestern']
    return res

pf=[]
header_fields=[]
filepath = '/content/HurriScan_Data/Hurdat.txt'
with open(filepath) as fp:
    ln = fp.readline()
    while ln:

        lt=identify_line_type(ln)

        details=[]
        if (lt==1):
            header_fields=process_header(ln)
            details=[]
        else:
            details=process_details(ln)
        if (details!=[]):
            n=list(header_fields[:-1])+list(details)

            pf.append(n)
        ln=fp.readline()

df=pd.DataFrame(pf)
df.columns=columns_name()
df.to_csv('hur.csv')
print(f'Number of samples before cleaning is: {df.shape[0]}')

#At this point, we have a dataframe with all of the Hurdat 2 data.
#Now let us clean it so it only has information about name, time and maximum windspeed

#Contains the columns we want to remove
columnList = list(df.columns)

#Remove columns we want to keep!
columnList.remove("Name")
columnList.remove("Year")
columnList.remove("Month")
columnList.remove("Day")
columnList.remove("Hours_in_UTC")
columnList.remove("Minutes_in_UTC")
columnList.remove("Maximum_sustained_wind_in_knots")
columnList.remove("Basin")

#Drop irrelevant columns
df = df.drop(columns = columnList)

#If it does not have a name, drop it from data
df = df[df['Name'] != 'UNNAMED']
df = df[df['Year'] > 1978]
df = df[df['Year'] < 2016]
#df = df[df['Maximum_sustained_wind_in_knots'] > 63]


#Add the Saffir Simpson (intensity rating, to our dataframe)
df['Saffir_Simpson_Rating'] = ''

#Add column for satellite image of hurricane
df['Satellite_Image'] = ''

rowNum = 0

#Update Saffir Simpson rating column based on maximum sustained windspeed column
for index, row in df.iterrows():
  if row['Maximum_sustained_wind_in_knots'] in range(64, 83):
    df['Saffir_Simpson_Rating'].values[rowNum] = 1
  elif row['Maximum_sustained_wind_in_knots'] in range(83, 96):
    df['Saffir_Simpson_Rating'].values[rowNum] = 2
  elif row['Maximum_sustained_wind_in_knots'] in range(96, 113):
    df['Saffir_Simpson_Rating'].values[rowNum] = 3
  elif row['Maximum_sustained_wind_in_knots'] in range(113, 137):
    df['Saffir_Simpson_Rating'].values[rowNum] = 4
  elif row['Maximum_sustained_wind_in_knots'] > 137:
    df['Saffir_Simpson_Rating'].values[rowNum] = 5
  else:
    df['Saffir_Simpson_Rating'].values[rowNum] = 0

  rowNum += 1

#Print out first couple of element to make sure we have done it correctly
print(f'Number of samples after cleaning is: {df.shape[0]}')
df.reset_index(inplace=True)
df.head()

#Wow! Now we have fully cleaned the Hurdat 2 data
# Out:
# ['.config', 'Images.npy', 'drive', 'hur.csv', 'HurriScan_Data', 'HurriScanData.npy', 'sample_data']
# Number of samples before cleaning is: 53976
# Number of samples after cleaning is: 14455
#    index Basin Name  Year  Month  Day  Hours_in_UTC  Minutes_in_UTC  \
# 0  33745    AL  ANA  1979      6   19             1              20
# 1  33746    AL  ANA  1979      6   19             1              80
# 2  33747    AL  ANA  1979      6   20             0               0
# 3  33748    AL  ANA  1979      6   20             0              60
# 4  33749    AL  ANA  1979      6   20             1              20
#
#    Maximum_sustained_wind_in_knots Saffir_Simpson_Rating Satellite_Image
# 0                             25.0                     0
# 1                             25.0                     0
# 2                             25.0                     0
# 3                             25.0                     0
# 4                             25.0                     0

# %%
#Data Acquisition and Cleaning for Hursat Data

imagesList = []

#First, check to see if we already have the data
print(os.getcwd())
os.chdir("/content/HurriScan_Data")

#If we have not already read the data
if not("Hursat" in os.listdir()):

  #Make the Hursat folder
  os.mkdir("Hursat")
  os.chdir("/content/HurriScan_Data/Hursat")

  #Initialize to starting year
  year = 2015
  numImages = 0

  #Keep adding data until we have 12000 images that match
  while year > 1977 and numImages < 12000:
    url = 'https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/' + str(year)

    #Get the webpage for the current year in Hursat data
    res = requests.get(url)
    soup = bs4.BeautifulSoup(res.text, "html.parser")

    #This line is from https://github.com/23ccozad/hurricane-wind-speed-cnn/blob/master/download.py to extract download url
    year_directory_file_urls = [url + '/' + node.get('href') for node in
                                      soup.find_all('a') if node.get('href').endswith('tar.gz')]

    #Iterate through all the .tar file urls
    for storm_url in year_directory_file_urls:
      #Now we need to check if this storm is in the Hurdat 2 data
      nameStorm = storm_url.split('_')[-2]
      yearStorm = int(storm_url.split('_')[3][:4])

      print(f'Storm Name: {nameStorm} and Year of Storm: {yearStorm}')
      print(f"Link: {storm_url}")

      #If the name is not in our Hurdat 2 dataset, we can skip as it will not be useful
      if not(nameStorm in df['Name'].values):
        print("Skipping as it is not in our Hurdat data")
        continue

      print("Found Match of storm name and year!")

      #Now we know that this storm is in the Hurdat data, we can read it's file to see if further information matches

      #First let us download the storm data from online
      # Open the .tar.gz and copy it's contents from the web, onto our computer
      path = os.getcwd() + '/' + nameStorm

      #Tar file and NetCDF processing code from https://github.com/23ccozad/hurricane-wind-speed-cnn/blob/master/download.py
      request = requests.get(storm_url, allow_redirects=True)
      open(nameStorm, 'wb').write(request.content)
      request.close()


      #response = requests.get(storm_url, stream=True)
      #if response.status_code == 200:
          #with open(path, 'wb') as f:
              #f.write(response.raw.read())
      #else:
        #print("error getting tar file")


      tar = tarfile.open(path)
      file_prefixes_in_directory = []
      for file_name in tar.getnames():

        #print(f"File Name: {file_name}")

        # Get the date and time of the satellite image, and the name of the satellite that took the image
        fulldate = file_name.split(".")[2] + file_name.split(".")[3] + file_name.split(".")[4]
        time = file_name.split(".")[5]

        # Determine whether the best track dataset has a record for the date and time of this storm.

        #print(f'Full Date: {fulldate} and time: {time}')
        #The types are strings of fulldate and time

        #Convert Hursat date format to Hurdat date format

        hursatYear = int(fulldate[0:4])

        if (fulldate[4] == '0'):
          hursatMonth = int(fulldate[5])
        else:
          hursatMonth = int(fulldate[4:6])

        if (fulldate[6] == '0'):
          hursatDay = int(fulldate[7])
        else:
          hursatDay = int(fulldate[6:])

        hursatTime = time[0:2]

        if (hursatTime[0] == '0'):
          hursatTime = int(hursatTime[1])
        else:
          hursatTime = int(hursatTime)


        #Check if the date and time is in the Hurdat 2 data


        #print(f"hursatYear: {hursatYear}, hursatMonth: {hursatMonth}, hursatDay: {hursatDay}, hursatTime: {hursatTime}")

        index_list = df[(df['Year'] == hursatYear)&(df['Month'] == hursatMonth)&(df['Day'] == hursatDay) & (df['Hours_in_UTC'] == hursatTime)].index.tolist()

        #print("Index List:")
        #print(index_list)

        #If the list of indices we received was empty, we did not find a match in Hurdat
        if (len(index_list) == 0):
          print("Did not find exact match in Hurdat Data Rows")
        #We found a match in Hurdat
        else:
          print("Found a match in Hurdat data")
          try:
              tar.extract(file_name, '/content/HurriScan_Data/Hursat')
          except KeyError:
              print(f"Warning: File '{file_name}' not found in the tar archive.")
              continue

          #Open the netCDF file and extract the image

          filePath = '/content/HurriScan_Data/Hursat/' + file_name

          dSet = nc.Dataset(filePath)
          #df['Satellite_Image'].values[index_list[0]] = dSet.variables['IRWIN'][0]
          #df.at['Satellite_Image', int(index_list[0])] = numImages
          print("Before: ")
          print(df.at[index_list[0], 'Satellite_Image'])
          #df.at[int(index_list[0]), 'Satellite_Image'] = numImages
          #df['Satellite_Image'][int(index_list[0])] = numImages
          imagesList.append(dSet.variables['IRWIN'][0])
          df.at[index_list[0], 'Satellite_Image'] = len(imagesList) - 1
          #numpArray[index_list[0]][9] = numImages
          print("After: ")
          print(df.at[index_list[0], 'Satellite_Image'])
          numImages += 1
      tar.close()
      print(" ***** DONE WITH THIS STORM **** \n\n")

    year -= 1
# Out:
# Streaming output truncated to the last 5000 lines.
# Found a match in Hurdat data
# Before:
# 6766
# After:
# 6767
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6768
# Found a match in Hurdat data
# Before:
# 6768
# After:
# 6769
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6770
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6771
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6772
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6773
# Found a match in Hurdat data
# Before:
# 6773
# After:
# 6774
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6775
# Found a match in Hurdat data
# Before:
# 6775
# After:
# 6776
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6777
# Found a match in Hurdat data
# Before:
# 6777
# After:
# 6778
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6779
# Found a match in Hurdat data
# Before:
# 6779
# After:
# 6780
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6781
#  ***** DONE WITH THIS STORM ****
#
#
# Storm Name: FERNANDA and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981219N12255_FERNANDA_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: GREG and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981225N16249_GREG_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: WARREN and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981226N16119_WARREN_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: VANESSA and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981226N17142_VANESSA_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: THAD and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981227N18129_THAD_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: MISSING and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981229N13327_MISSING_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: HILARY and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981234N18253_HILARY_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: AGNES and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981237N16148_AGNES_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: MISSING and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981239N21267_MISSING_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: IRWIN and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981240N17257_IRWIN_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: EMILY and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981244N30287_EMILY_c20170721.tar.gz
# Found Match of storm name and year!
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6782
# Found a match in Hurdat data
# Before:
# 6782
# After:
# 6783
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6784
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6785
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6786
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6787
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6788
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6789
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6790
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6791
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6792
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6793
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6794
#  ***** DONE WITH THIS STORM ****
#
#
# Storm Name: BILL and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981245N23161_BILL_c20170721.tar.gz
# Found Match of storm name and year!
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
# 6784
# After:
# 6795
# Found a match in Hurdat data
# Before:
# 6795
# After:
# 6796
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
# 6785
# After:
# 6797
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
# 6786
# After:
# 6798
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
# 6787
# After:
# 6799
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
# 6788
# After:
# 6800
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
# 6789
# After:
# 6801
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
# 6790
# After:
# 6802
# Found a match in Hurdat data
# Before:
# 6802
# After:
# 6803
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
#  ***** DONE WITH THIS STORM ****
#
#
# Storm Name: FLOYD and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981247N16300_FLOYD_c20170721.tar.gz
# Found Match of storm name and year!
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
# 6798
# After:
# 6804
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
# 6799
# After:
# 6805
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
# 6800
# After:
# 6806
# Found a match in Hurdat data
# Before:
# 6806
# After:
# 6807
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
# 6801
# After:
# 6808
# Found a match in Hurdat data
# Before:
# 6808
# After:
# 6809
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
# 6803
# After:
# 6810
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
# 6791
# After:
# 6811
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
# 6792
# After:
# 6812
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
# 6793
# After:
# 6813
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
# 6794
# After:
# 6814
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
#  ***** DONE WITH THIS STORM ****
#
#
# Storm Name: GERT and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981250N15306_GERT_c20170721.tar.gz
# Found Match of storm name and year!
# Found a match in Hurdat data
# Before:
# 6809
# After:
# 6815
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
# 6810
# After:
# 6816
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
# 6811
# After:
# 6817
# Found a match in Hurdat data
# Before:
# 6817
# After:
# 6818
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
# 6812
# After:
# 6819
# Found a match in Hurdat data
# Before:
# 6819
# After:
# 6820
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
# 6813
# After:
# 6821
# Found a match in Hurdat data
# Before:
# 6821
# After:
# 6822
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
# 6814
# After:
# 6823
# Found a match in Hurdat data
# Before:
# 6823
# After:
# 6824
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6825
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6826
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
#  ***** DONE WITH THIS STORM ****
#
#
# Storm Name: MISSING and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981255N12286_MISSING_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: HARVEY and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981255N14311_HARVEY_c20170721.tar.gz
# Found Match of storm name and year!
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
# 6824
# After:
# 6827
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
# 6825
# After:
# 6828
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
# 6826
# After:
# 6829
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6830
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6831
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6832
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6833
#  ***** DONE WITH THIS STORM ****
#
#
# Storm Name: CLARA and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981256N10150_CLARA_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: JOVA and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981258N15237_JOVA_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: DOYLE and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981261N25174_DOYLE_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: KNUT and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981262N16256_KNUT_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: MISSING and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981265N14117_MISSING_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: IRENE and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981265N14328_IRENE_c20170721.tar.gz
# Found Match of storm name and year!
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6834
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6835
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6836
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6837
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6838
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6839
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6840
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6841
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6842
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6843
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
#  ***** DONE WITH THIS STORM ****
#
#
# Storm Name: ELSIE and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981266N09151_ELSIE_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: MISSING and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981269N08322_MISSING_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: MISSING and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981277N21116_MISSING_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: LIDIA and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981280N20250_LIDIA_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: MAX and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981281N15245_MAX_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: NORMA and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981282N15256_NORMA_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: FABIAN and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981283N07132_FABIAN_c20170721.tar.gz
# Found Match of storm name and year!
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
#  ***** DONE WITH THIS STORM ****
#
#
# Storm Name: GAY and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981286N10150_GAY_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: ALEX and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981291S05081_ALEX_c20170721.tar.gz
# Found Match of storm name and year!
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
#  ***** DONE WITH THIS STORM ****
#
#
# Storm Name: OTIS and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981297N11261_OTIS_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: MISSING and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981298N06083_MISSING_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: JOSE and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981303N25313_JOSE_c20170721.tar.gz
# Found Match of storm name and year!
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6844
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6845
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6846
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6847
#  ***** DONE WITH THIS STORM ****
#
#
# Storm Name: ARMELLE and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981306S03096_ARMELLE_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: KATRINA and Year of Storm: 1981
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1981/HURSAT_b1_v06_1981307N17279_KATRINA_c20170721.tar.gz
# Found Match of storm name and year!
# Found a match in Hurdat data
# Before:
#
# After:
# 6848
# Found a match in Hurdat data
# Before:
# 6848
# After:
# 6849
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6850
# Found a match in Hurdat data
# Before:
# 6850
# After:
# 6851
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6852
# Found a match in Hurdat data
# Before:
# 6852
# After:
# 6853
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Found a match in Hurdat data
# Before:
#
# After:
# 6854
# Found a match in Hurdat data
# Before:
# 6854
# After:
# 6855
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# Did not find exact match in Hurdat Data Rows
# ...
# Skipping as it is not in our Hurdat data
# Storm Name: OWEN and Year of Storm: 1979
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1979/HURSAT_b1_v06_1979262N15149_OWEN_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: 05B and Year of Storm: 1979
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1979/HURSAT_b1_v06_1979264N10087_05B_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: PAMELA and Year of Storm: 1979
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1979/HURSAT_b1_v06_1979266N18150_PAMELA_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: MISSING and Year of Storm: 1979
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1979/HURSAT_b1_v06_1979269N19133_MISSING_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: SARAH and Year of Storm: 1979
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1979/HURSAT_b1_v06_1979271N13113_SARAH_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: ROGER and Year of Storm: 1979
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1979/HURSAT_b1_v06_1979273N11145_ROGER_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: TIP and Year of Storm: 1979
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1979/HURSAT_b1_v06_1979275N05159_TIP_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: HILDA and Year of Storm: 1979
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1979/HURSAT_b1_v06_1979277N13256_HILDA_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: MISSING and Year of Storm: 1979
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1979/HURSAT_b1_v06_1979286N17273_MISSING_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: MISSING and Year of Storm: 1979
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1979/HURSAT_b1_v06_1979290N11112_MISSING_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: IGNACIO and Year of Storm: 1979
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1979/HURSAT_b1_v06_1979297N12265_IGNACIO_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: SUBTROP and Year of Storm: 1979
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1979/HURSAT_b1_v06_1979297N29294_SUBTROP_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: MISSING and Year of Storm: 1979
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1979/HURSAT_b1_v06_1979298N12283_MISSING_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: VERA and Year of Storm: 1979
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1979/HURSAT_b1_v06_1979300N04166_VERA_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: 06B and Year of Storm: 1979
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1979/HURSAT_b1_v06_1979300N06095_06B_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: WAYNE and Year of Storm: 1979
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1979/HURSAT_b1_v06_1979311N10142_WAYNE_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: MISSING and Year of Storm: 1979
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1979/HURSAT_b1_v06_1979312N25304_MISSING_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: 07A and Year of Storm: 1979
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1979/HURSAT_b1_v06_1979317N10072_07A_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: JIMENA and Year of Storm: 1979
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1979/HURSAT_b1_v06_1979319N09272_JIMENA_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: 08B and Year of Storm: 1979
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1979/HURSAT_b1_v06_1979327N08088_08B_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: 01S and Year of Storm: 1979
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1979/HURSAT_b1_v06_1979329S07086_01S_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: ABBY and Year of Storm: 1979
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1979/HURSAT_b1_v06_1979333N07169_ABBY_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: 26W and Year of Storm: 1979
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1979/HURSAT_b1_v06_1979333N12153_26W_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: OFA and Year of Storm: 1979
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1979/HURSAT_b1_v06_1979344S12170_OFA_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: ALETTA and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978151N15260_ALETTA_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: BUD and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978168N11242_BUD_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: CARLOTTA and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978168N14254_CARLOTTA_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: MISSING and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978173N25274_MISSING_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: DANIEL and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978178N14260_DANIEL_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: MISSING and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978181N14235_MISSING_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: EMILIA and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978188N15248_EMILIA_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: FICO and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978190N11254_FICO_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: MISSING and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978192N16333_MISSING_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: GILMA and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978194N11261_GILMA_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: HECTOR and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978203N13260_HECTOR_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: AMELIA and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978212N26263_AMELIA_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: BESS and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978218N25270_BESS_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: MISSING and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978220N13308_MISSING_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: CORA and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978220N13325_CORA_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: MISSING and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978222N27270_MISSING_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: IVA and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978223N18252_IVA_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: JOHN and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978230N12239_JOHN_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: LANE and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978231N13224_LANE_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: KRISTY and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978231N14251_KRISTY_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: MIRIAM and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978236N11245_MIRIAM_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: DEBRA and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978239N23272_DEBRA_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: ELLA and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978242N26300_ELLA_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: NORMAN and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978243N13262_NORMAN_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: MISSING and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978243N28269_MISSING_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: FLOSSIE and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978247N12321_FLOSSIE_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: MISSING and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978247N14344_MISSING_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: MISSING and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978251N12261_MISSING_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: MISSING and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978252N23266_MISSING_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: HOPE and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978255N30280_HOPE_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: GRETA and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978257N11298_GRETA_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: MISSING and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978262N13344_MISSING_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: OLIVIA and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978263N16267_OLIVIA_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: MISSING and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978265N20269_MISSING_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: PAUL and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1978266N14260_PAUL_c20170721.tar.gz
# Skipping as it is not in our Hurdat data
# Storm Name: ROSA and Year of Storm: 1978
# Link: https://www.ncei.noaa.gov/data/hurricane-satellite-hursat-b1/archive/v06/1978/HURSAT_b1_v06_1
#fig = plt.figure(figsize=(301, 301))

# loop over images
#for i in range(len(imagesList)):
    #img = np.reshape(imagesList[i : (i + 1)], (301, 301))
    #fig.add_subplot(len(imagesList)//2, len(imagesList)//2, i + 1)
    #plt.imshow(img)

#for image in imagesList:
  #plt.imshow(image)

# %%
df.head(1000)
# Out:
#      index Basin     Name  Year  Month  Day  Hours_in_UTC  Minutes_in_UTC  \
# 0    33745    AL      ANA  1979      6   19             1              20
# 1    33746    AL      ANA  1979      6   19             1              80
# 2    33747    AL      ANA  1979      6   20             0               0
# 3    33748    AL      ANA  1979      6   20             0              60
# 4    33749    AL      ANA  1979      6   20             1              20
# ..     ...   ...      ...   ...    ...  ...           ...             ...
# 995  35208    AL  ALBERTO  1982      6    3             0               0
# 996  35209    AL  ALBERTO  1982      6    3             0              60
# 997  35210    AL  ALBERTO  1982      6    3             1              20
# 998  35211    AL  ALBERTO  1982      6    3             1              80
# 999  35212    AL  ALBERTO  1982      6    4             0               0
#
#      Maximum_sustained_wind_in_knots Saffir_Simpson_Rating Satellite_Image
# 0                               25.0                     0
# 1                               25.0                     0
# 2                               25.0                     0
# 3                               25.0                     0
# 4                               25.0                     0
# ..                               ...                   ...             ...
# 995                             30.0                     0
# 996                             40.0                     0
# 997                             50.0                     0
# 998                             75.0                     1
# 999                             65.0                     1
#
# [1000 rows x 11 columns]

# %%
len(imagesList)
# Out:
# 7100

# %%
#Get rid of any rows in the dataframe that don't correpond to images
df['Satellite_Image'].replace('', np.nan, inplace=True)
df.dropna(subset=['Satellite_Image'], inplace=True)

#Drop irrelevant columns in dataframe (drop all except rating and index of image)
columnList = list(df.columns)
columnList.remove("Satellite_Image")
columnList.remove("Saffir_Simpson_Rating")
df = df.drop(columns = columnList)
df.head(10)

ratings_list = df['Saffir_Simpson_Rating'].tolist()
image_indices = df['Satellite_Image'].tolist()
images = []
for index in image_indices:
  images.append(imagesList[int(index)])

#Sanity check!
#plt.imshow(images[0])
#plt.imshow(imagesList[6971])

# %%
#Convert Image data List to a numpy array
imageData = np.array(images)
intensity_ratings = np.array(ratings_list)

#The number of training images we have
print(f"The number of labels we have to train with is: {intensity_ratings.shape[0]}")
print(f"The number of images we have to train with is: {len(imageData)}")

#Save our numpy arrays so that they may easily be loaded in the future
np.save('/content/Images.npy', imageData)
np.save('/content/IntensityRatings.npy', intensity_ratings)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c1abdd619d9f> in <cell line: 3>()
#       1 #Convert Image data List to a numpy array
#       2 #imageData = np.array(imagesList)
# ----> 3 imageData = np.array(images)
#       4 intensity_ratings = np.array(ratings_list)
#       5
#
# NameError: name 'np' is not defined

# %%
#Mount Google Drive and save .npy files to them
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import drive
drive.mount('/content/drive')

#Please replace the variable with your custom path when you want to run the notebook
claire = 'APS360_Team_11_Project_Folder'
sean = 'University/Third_Year/APS360/APS360_Project'
charlotte = ''
thardchi = ''

#Save Images and Labels to Shared Google Drive
shutil.copy("/content/Images.npy",f"/content/drive/MyDrive/{claire}/HurriScan_Data")
shutil.copy("/content/IntensityRatings.npy",f"/content/drive/MyDrive/{claire}/HurriScan_Data")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '/content/drive/MyDrive/APS360_Team_11_Project_Folder/HurriScan_Data/IntensityRatings.npy'
